# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.spatial import ConvexHull
from mpl_toolkits import mplot3d

import sys
sys.path.append('../scripts')

from region import AcquisitionRegion

import pickle as pkl

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import geometry_msgs
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-0527044959bd> in <module>
# ----> 1 import geometry_msgs
#
# ModuleNotFoundError: No module named 'geometry_msgs'

# %%
with open('../data/corners.pkl', 'rb') as f:
    corners = pkl.load(f)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-b4689a81946e> in <module>
#       1 with open('../data/corners.pkl', 'rb') as f:
# ----> 2     corners = pkl.load(f)
#
# ModuleNotFoundError: No module named 'geometry_msgs'

# %%
points = np.array([[1.1,1.0,0.0],[1.0,0.0,1.0],[0.0,0.5,0.0],[0.8,0.4,0.0]])
region = AcquisitionRegion(points)

# %%
grid = region.grid(0.05)

# %%
ax = plt.axes(projection='3d')
ax = plt.axes(projection='3d')
for s in region.hull.simplices:
    s = list(s)+[s[0]]
    ax.plot3D(points[s,0],points[s,1],points[s,2])
ax.scatter3D(grid[:,0],grid[:,1],grid[:,2])
plt.show()

# %%
len(grid)
# Out:
# 746

# %%
randPos = region.randomPos(750)

# %%
ax = plt.axes(projection='3d')
ax = plt.axes(projection='3d')
for s in region.hull.simplices:
    s = list(s)+[s[0]]
    ax.plot3D(points[s,0],points[s,1],points[s,2])
ax.scatter3D(randPos[:,0],randPos[:,1],randPos[:,2])
plt.show()
